# %% [markdown]
# # **Bike Sales in Europe**

# %% [markdown]
# ## Objectives
#
# * In this unit I will explore the use of ethical research and what steps have been taken to approach dilemas or mention insights.
#
# * I have chosen this dataset because it is able to give me a Region, three age ranges and States. where as my usual 'Online Marketing Performance' datasets haven't provided such information.
#
# ## Inputs & Outputs
#
# * As usual I commented the commands in the Code Markdowns and they have provided the predictive text/code and I have my desired results, this is the first time I have not relied on ChatGPT for codes but I have asked Copilot to fix my reoccuring problem of two Virtual Environments and has worked!
#
# * This time instead of providing the graphs/charts in VSCode, I cleaned the dataset for what I intended to research with what matched the objective, In Tableau I felt more comfortable and confident in my presentation power to deliver accurate, if not sound information.
#
# * In regards of ethics in this dataset I thought it would be an interesting insight that there was no 'Other' or 'They/Them' column when researching the Age and Genders of the cyclists, this I think is due to how much information there is in the dataset or possibly the release of the dataset? recent events or movements? I can't say.
#
# * I did think when the title of the dataset is "Bikes sold in Europe" why United States, Canada and Australia were included, having removed those three columns it's safe to assume that the results of "Where has the most cyclists?", "What are the age ranges in the other Countries?" and "Who cycles more, Men or Women?" would be different, perhaps next time I will concentrate on a wider parts of the world.
#
# * Upon reflection and concentration on Genders, Age Groups and Regions, I have neglected the Year and possibly Months columns. Though I am happy with the results/conclusion, I suspect I should of had a times/year of purchase between 2013-2016 but even then I feel that I would have numerous sections/segments of Male and Female, followed by Age Groups (Youth, Young Adult, Adult and Senior) and between 2013-16.
#
# ## Additional Comments
#
# This is a dataset was found on Kaggle, created by S. Shah.

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# Directory

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\PC\\Documents\\vs_code\\Unit3\\Unit3-Bike-Sales-in-Europe\\jupyter_notebooks'

# %% [markdown]
# Directory path

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\PC\\Documents\\vs_code\\Unit3\\Unit3-Bike-Sales-in-Europe'

# %% [markdown]
# # Section 1

# %% [markdown]
# Loading the Dataset.

# %%
import sys
import subprocess
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_name = "Sales.csv"
sales_data = pd.read_csv(file_name)
sales_data.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Section 2

# %% [markdown]
# Cleaning and managing data.

# %%
# show me the locations from the data
sales_data['Country'].unique()
# Out:
# <StringArray>
# ['Canada', 'Australia', 'United States', 'Germany', 'France',
#  'United Kingdom']
# Length: 6, dtype: str

# %% [markdown]
# This was the first thing to catch my eye, interesting that the dataset said "Europe" yet Canada, Australia and United States are in here.
#
# I chose this dataset thinking it was just European countries so I'll be keeping Germany, France and United Kingdom because they are at least within distance. This might effect some of the other columns, but the first inaccuracy I think was including Canada, United States and Australia.

# %%
#show me states from the data for United Kingdom, Germany, and France
sales_data[sales_data['Country'].isin(['United Kingdom', 'Germany', 'France'])]['State'].unique()
# Out:
# <StringArray>
# [           'Saarland',   'Seine Saint Denis',             'Moselle',
#              'England',                'Nord',              'Hessen',
#  'Nordrhein-Westfalen',             'Hamburg',        'Loir et Cher',
#        'Seine (Paris)',              'Loiret',              'Bayern',
#       'Hauts de Seine',             'Yveline',             'Essonne',
#           'Val d'Oise',      'Seine et Marne',        'Val de Marne',
#        'Pas de Calais',   'Charente-Maritime',     'Garonne (Haute)',
#          'Brandenburg',               'Somme']
# Length: 23, dtype: str

# %%
#show me a list of the products from the data
sales_data['Product'].unique()
# Out:
# <StringArray>
# [    'Hitch Rack - 4-Bike',  'All-Purpose Bike Stand',
#     'Mountain Bottle Cage',   'Water Bottle - 30 oz.',
#         'Road Bottle Cage',            'AWC Logo Cap',
#    'Bike Wash - Dissolver',   'Fender Set - Mountain',
#    'Half-Finger Gloves, L',   'Half-Finger Gloves, M',
#  ...
#  'Touring-1000 Yellow, 54',   'Touring-2000 Blue, 54',
#    'Touring-3000 Blue, 50', 'Touring-3000 Yellow, 58',
#    'Touring-2000 Blue, 46',   'Touring-2000 Blue, 50',
#    'Touring-2000 Blue, 60',         'Classic Vest, L',
#          'Classic Vest, M',         'Classic Vest, S']
# Length: 130, dtype: str

# %%
#remove United States, Canada, and Australia from the data, call this "Cleaned_Data"
Cleaned_Data = sales_data[~sales_data['Country'].isin(['United States', 'Canada', 'Australia'])]

# %% [markdown]
# After close inspection of the original dataset I have decided to remove United States, Canada and Australia due to distance and possibly surpass/overthrow Germany, France and United Kingdom when I want to Visualise the data later.

# %%
#save Cleaned_Data to a new CSV file called "Cleaned_Sales.csv"
Cleaned_Data.to_csv("Cleaned_Sales.csv", index=False)

# %% [markdown]
# As I've removed columns and have read through the dataset, I think saving the new .csv file at this point is wise as I can then move over to Tableau.

# %% [markdown]
# ---

# %% [markdown]
# * Task Notes
#
# The objective for the unit is to consider ethics, with the previous datasets I've used (Online Marketing Performance) I don't recall Who was clicking, What nationality, race or ethnicity. What the advert was for and who was the target audience.
#
# I've chosen this dataset (Bikes sold in Europe) because it has provided nationality, gender and age. I am able to see what has been purchased and in what quantity, I do feel that this time looking at cost, revenue, unit price and profit might detour away from the ethics when I visualise that in Tableau.
#
# In Tableau I will make another ring chart providing gender as centre, age in the middle and possibly what has been purchased (Bikes, Helmets and equipment). Possibly a bit more 'playing around' I will need to include nationality as I think it would be interesting to see where has the most bikes sold.
#
# My considerations when approaching the ethics is, I'm not using this information to find out a individuals finance or income, nor is it to find out which country is richer or poorer, Why does the individual cycle, Because of pollution? I won't find that answer with the information I have been provided.
#
# I might find who and where has the best scenic cycle routes with less traffic.

# %% [markdown]
# ---

# %% [markdown]
# * Research and Ethical Insights
#
# In Tableau.
#
# Sheet 1. I have made the radial chart giving me the information of how many Male and Female customers there are, Followed by age groups, this is the total disregarding their nationalties. I then realised an ethical problem and this would be Gender Reassignment and or Sexual Orientation. Without going into further detail such pronouns, there is not a column for "They/Them" or "Other" this I feel would have also been valuable information as another interesting factor to be explored.
#
# Sheet 2. I have made a world map showing me where in Europe has the most cyclists, I have deduced that the "Customer Gender" column would also show me the sales, though not needed. The problem I find with this map is 'What defines this total?' Because I've only used one value and not age. I do think this has worked to the extent of it's included the age group because there is a total of Male and Female cyclists from sheet 1.
#
# Ethical problem, UK has 13,620, Germany has 11,098 and France has 10,998 worth of cyclists. Like I mentioned before except I wouldn't say 'due to pollution/car emissions' I think the fact is Germany and France are bigger than the UK, possibly more transportation (cars, trains and buses) going further distance plus I haven't got personal information such as 'Where and what the cyclist/user does for work?' or their commutes.
#
# Sheet 3. I have included the Age group with Genders and their Countries, this has presented the data in a more effective way. It has revealed that the UK has more cyclists, mostly males in Europe cycle with a score of 629,556 alongside females with a score of 627,842 and the retirement age is 64+ (Seniors).
#
# Regarding ethics with these findings as I mentioned before there isn't a column/section for Other (They/Them) I do feel that it would have made the research interesting as there could be that option/column for another dataset that has yet to be explored.
#
# Age Groups I'm happy with my findings but a consideration for this would be the User/Cyclist's income or health as inflation increases in general, they might prefer to save money and increase their health and as cycling is also the healthier for the environment.
#
# Nationality/Countries, I'm surprised at the result with the UK with 13,620 cyclists as I thought Germany or France would have had the most. I will definatley consider geographical location and their transportation, this is due to questions like 'How big are their countrysides?', 'Where is the next town/city?' and again 'What do they do for work/commutes?'.

# %% [markdown]
# ---

# %% [markdown]
# # Conclusion & Next Steps

# %% [markdown]
# * I have finally made a VSCode file with 1 Virtual Environment!
#
# * I feel that I have presented the data efficiently alongside effective considerations regarding ethics in this unit and they are Age, Gender Reasignment, Sexual Orientation, Sex and a brief consideration following the rules of the GDPR (General Data Protection Regulation) such as individuals income, state of province, personal and private information.
#
# * I will find a dataset with the best scenic cycle routes.
